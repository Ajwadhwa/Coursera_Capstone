# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction:Business Problem <a name="analysis"></a>

# %% [markdown]
# For food enthuiast wanted to idenitfy how they can find places serves best steak in New York
#   - Challange is many stakehouse in the city so it is very hard to search for good one
#   - Searching ratings by neighbhourhood is time consuming and tedious task
#   - Areas which have potential stakehouse growth opportunities
#
# Interested Audience
#    - People visiting New York City and surroundings
#    - Stake lovers wanted to taste best available steak in town
#    - Entrepreneurs wanted to open steak resturant in NY

# %% [markdown]
# ## Data

# %% [markdown]
# ##### Description of the Data:
# The following data is required to answer the issues of the problem:
#
#     - List of Boroughs and neighborhoods of New York with their geodata (latitud and longitud)
#     - List of steak resturants in Borough
#     - Foursquare API to get list of venues, ratings, tips and other required details
#
# ##### how it will be used to solve the problem
# The data will be used as follows:
#
#     -Data will be collected through Foursquare API's and Council
#     -Data will be sorted and enriched to generate meaningful analytics
#     -Finally data will be sorted with key attributes and plotted on geo maps for visualisation

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project efforts are directed to New York City that has high number of people looking to dine out for Steak and looking for quality food and services
#
# Firstly data is collected using Foursquare APIs which provides location of steak resturants in New York City Borough and its Neighbourhood, they are filtered by Likes, Ratings and Tips once we have got all this informaiton, a subset of dataframe is creating resturnats for which rating is 8 and above.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Once data was shortlisted where ratings are 8 and above it was gave 29 restults which helped consumer to shortlist neighbourhoods providing good steak.

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# As per restuts we can see highest ratings with West Village followed by South Side
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# With data we have conslusive evidence that best steak are offered in West Village in Manhattan so if someone loves Steak this is the place to visit.
# ![image.png](attachment:image.png)
