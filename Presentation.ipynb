# %% [markdown]
# # Presentation

# %% [markdown]
# ## Finding best Steak places in New York

# %% [markdown]
# ##### Introduction
# - New York is multicultural city with polupationof 8.39 millions in 2018, it comprises of 5 boroughs sittings where the hudson river meets Atlantic Ocena.
# - Finding best steak place is bit of a challange for people love to eat steak
# - Identified few places offering steaks which is diverse in location and offering

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data Description

# %% [markdown]
# The following data is required to answer the issues of the problem:
#
#     - List of Boroughs and neighborhoods of New York with their geodata (latitud and longitud)
#     - List of steak resturants in Borough
#     - Foursquare API to get list of venues, ratings, tips and other required details
#
# ### how it will be used to solve the problem
# The data will be used as follows:
#
#     -Data will be collected through Foursquare API's and Council
#     -Data will be sorted and enriched to generate meaningful analytics
#     -Finally data will be sorted with key attributes and plotted on geo maps for visualisation

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project efforts are directed to New York City that has high number of people looking to dine out for Steak and looking for quality food and services
#
# Firstly data is collected using Foursquare APIs which provides location of steak resturants in New York City Borough and its Neighbourhood, they are filtered by Likes, Ratings and Tips once we have got all this informaiton, a subset of dataframe is creating resturnats for which rating is 8.5 and above.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Once data was shortlisted where ratings are 8.5 and above it was gave 8 restults which helped consumer to shortlist neighbourhoods providing good steak.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# With data we have conslusive evidence that best steak are offered in West Village in Manhattan so if someone loves Steak this is the place to visit.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
